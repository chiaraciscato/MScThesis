# %%
import netCDF4 as nc
from netCDF4 import Dataset
import matplotlib as mpl
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
import pandas as pd

# %%
import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cfeature
import cmocean
import seaborn as sns

# %%
# for file_name in glob.glob('/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/*'):
#     print(file_name)

# %%
list_netcdf = []
for file_name in glob.glob("/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/*.nc"):
    list_netcdf.append(file_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hq/35w1hmb96js9vgqq4730r3780000gn/T/ipykernel_14869/786816764.py in <module>
#       1 list_netcdf = []
# ----> 2 for file_name in glob.glob("/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/*.nc"):
#       3     list_netcdf.append(file_name)
#
# NameError: name 'glob' is not defined

# %%
ds = xarray.open_mfdataset('/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/*.nc')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hq/35w1hmb96js9vgqq4730r3780000gn/T/ipykernel_14869/865062680.py in <module>
# ----> 1 ds = xarray.open_mfdataset('/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/*.nc')
#
# NameError: name 'xarray' is not defined

# %%
lats = ds.variables['nav_lat'][:]
lons = ds.variables['nav_lon'][:]
time = ds.variables['time_counter'][:]
ph = ds.variables['ph'][:]
co2flux = ds.variables['co2flux_cpl'][:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hq/35w1hmb96js9vgqq4730r3780000gn/T/ipykernel_14869/229328394.py in <module>
# ----> 1 lats = ds.variables['nav_lat'][:]
#       2 lons = ds.variables['nav_lon'][:]
#       3 time = ds.variables['time_counter'][:]
#       4 ph = ds.variables['ph'][:]
#       5 co2flux = ds.variables['co2flux_cpl'][:]
#
# NameError: name 'ds' is not defined

# %%
ds.ph.mean(dim=('y', 'x')).plot(figsize= (12, 4)) # global mean for pH without OAE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hq/35w1hmb96js9vgqq4730r3780000gn/T/ipykernel_14869/433957592.py in <module>
# ----> 1 ds.ph.mean(dim=('y', 'x')).plot(figsize= (12, 4)) # global mean for pH without OAE
#
# NameError: name 'ds' is not defined

# %%
df = ds.sel(time_counter=slice('2090', '2100'))

# %%
dataframe = df.to_dataframe()

# %%
dataframe.head()
# Out:
#                              time_counter_bnds  nav_lon    nav_lat  co2flx  \
# time_counter        bnds y x
# 2090-01-16 12:00:00 0    0 0        2090-01-01    72.75 -77.010475     0.0
#                            1        2090-01-01    73.25 -77.010475     0.0
#                            2        2090-01-01    73.75 -77.010475     0.0
#                            3        2090-01-01    74.25 -77.010475     0.0
#                            4        2090-01-01    74.75 -77.010475     0.0
#
#                                     ph  co2flux_cpl
# time_counter        bnds y x
# 2090-01-16 12:00:00 0    0 0  7.751746          0.0
#                            1  7.751746          0.0
#                            2  7.751746          0.0
#                            3  7.751746          0.0
#                            4  7.751746          0.0

# %%
dataframe.describe()
# Out:
#             nav_lon       nav_lat        co2flx            ph   co2flux_cpl
# count  8.854608e+07  8.854608e+07  8.854608e+07  8.854608e+07  8.854608e+07
# mean  -1.020398e+00  5.172927e-01 -5.736711e-10  7.900808e+00 -3.475935e-10
# std    1.025694e+02  5.207631e+01  2.090503e-09  1.415216e-01  2.123312e-09
# min   -1.799970e+02 -7.701048e+01 -2.677337e-08  5.556356e+00 -2.192818e-08
# 25%   -9.518312e+01 -5.194667e+01 -1.231162e-09  7.751746e+00 -1.151288e-09
# 50%    2.482575e+00  2.998630e+00  0.000000e+00  7.970784e+00  0.000000e+00
# 75%    8.425000e+01  5.047917e+01  0.000000e+00  8.009940e+00  2.534096e-10
# max    1.799988e+02  8.988536e+01  5.063441e-08  8.288778e+00  4.110115e-08

# %%
df.ph.mean(dim=('y', 'x')).plot(figsize= (12, 4)) # global from 2090 to 2100

# %%
ds.ph.mean(dim=('time_counter')).plot(figsize = (10, 4))

# %%
sliced_data = ds.where((-25 < ds.nav_lon) & (ds.nav_lon < 10) & (35 < ds.nav_lat) & (ds.nav_lat < 70), drop=True)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/hq/35w1hmb96js9vgqq4730r3780000gn/T/ipykernel_12442/3669238944.py in <module>
# ----> 1 sliced_data = ds.where((-25 < ds.nav_lon) & (ds.nav_lon < 10) & (35 < ds.nav_lat) & (ds.nav_lat < 70), drop=True)
#
# /opt/anaconda3/envs/GEOMAR/lib/python3.7/site-packages/xarray/core/common.py in where(self, cond, other, drop)
#    1286             indexers = {k: np.unique(v) for k, v in nonzeros}
#    1287
# -> 1288             self = self.isel(**indexers)
#    1289             cond = cond.isel(**indexers)
#    1290
#
# /opt/anaconda3/envs/GEOMAR/lib/python3.7/site-packages/xarray/core/dataset.py in isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2367             var_indexers = {k: v for k, v in indexers.items() if k in var_value.dims}
#    2368             if var_indexers:
# -> 2369                 var_value = var_value.isel(var_indexers)
#    2370                 if drop and var_value.ndim == 0 and var_name in coord_names:
#    2371                     coord_names.remove(var_name)
#
# /opt/anaconda3/envs/GEOMAR/lib/python3.7/site-packages/xarray/core/variable.py in isel(self, indexers, missing_dims, **indexers_kwargs)
#    1191
#    1192         key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1193         return self[key]
#    1194
#    1195     def squeeze(self, dim=None):
#
# /opt/anaconda3/envs/GEOMAR/lib/python3.7/site-packages/xarray/core/variable.py in __getitem__(self, key)
#     784         """
#     785         dims, indexer, new_order = self._broadcast_indexes(key)
# --> 786         data = as_indexable(self._data)[indexer]
#     787         if new_order:
#     788             data = np.moveaxis(data, range(len(new_order)), new_order)
#
# /opt/anaconda3/envs/GEOMAR/lib/python3.7/site-packages/xarray/core/indexing.py in __getitem__(self, key)
#    1158     def __getitem__(self, key):
#    1159         array, key = self._indexing_array_and_key(key)
# -> 1160         return array[key]
#    1161
#    1162     def __setitem__(self, key, value):
#
# /opt/anaconda3/envs/GEOMAR/lib/python3.7/site-packages/dask/array/core.py in __getitem__(self, index)
#    1890
#    1891         out = "getitem-" + tokenize(self, index2)
# -> 1892         dsk, chunks = slice_array(out, self.name, self.chunks, index2, self.itemsize)
#    1893
#    1894         graph = HighLevelGraph.from_collections(out, dsk, dependencies=[self])
#
# /opt/anaconda3/envs/GEOMAR/lib/python3.7/site-packages/dask/array/slicing.py in slice_array(out_name, in_name, blockdims, index, itemsize)
#     172
#     173     # Pass down to next function
# --> 174     dsk_out, bd_out = slice_with_newaxes(out_name, in_name, blockdims, index, itemsize)
#     175
#     176     bd_out = tuple(map(tuple, bd_out))
#
# /opt/anaconda3/envs/GEOMAR/lib/python3.7/site-packages/dask/array/slicing.py in slice_with_newaxes(out_name, in_name, blockdims, index, itemsize)
#     194
#     195     # Pass down and do work
# --> 196     dsk, blockdims2 = slice_wrap_lists(out_name, in_name, blockdims, index2, itemsize)
#     197
#     198     if where_none:
#
# /opt/anaconda3/envs/GEOMAR/lib/python3.7/site-packages/dask/array/slicing.py in slice_wrap_lists(out_name, in_name, blockdims, index, itemsize)
#     240     ]
#     241     if len(where_list) > 1:
# --> 242         raise NotImplementedError("Don't yet support nd fancy indexing")
#     243     # Is the single list an empty list? In this case just treat it as a zero
#     244     # length slice
#
# NotImplementedError: Don't yet support nd fancy indexing

# %%
sliced_data.ph.mean(dim=('time_counter')).plot(figsize = (10, 4))

# %%
ds_season = ds.ph.groupby('time_counter.season').mean('time_counter')
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(16,10))
i = 0
for j, season in enumerate(('DJF', 'MAM', 'JJA', 'SON')):
    if season =='JJA':
        i += 1
        j = 0
        
    elif season =='SON':
        j = 1
        
    ds_season.sel(season=season).plot.pcolormesh(
        ax=axes[j, i], vmin=7.2, vmax=8.2, cmap='RdBu_r',
        add_colorbar=True, extend='both')
    
for ax in axes.flat:
    ax.axes.get_xaxis().set_ticklabels([])
    ax.axes.get_yaxis().set_ticklabels([])
    ax.axes.axis('tight')

plt.tight_layout()
fig.suptitle('pH', fontsize=16, y=1.02)

# %%
# regional from 2015 to 2100

ds_season = sliced_data.ph.groupby('time_counter.season').mean('time_counter')
fig_region, axes = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
i = 0
for j, season in enumerate(('DJF', 'MAM', 'JJA', 'SON')):
    if season =='JJA':
        i += 1
        j = 0
        
    elif season =='SON':
        j = 1
        
    ds_season.sel(season=season).plot.pcolormesh(
        ax=axes[j, i], vmin=7.2, vmax=8.2, cmap='RdBu_r',
        add_colorbar=True, extend='both')
    
for ax in axes.flat:
    ax.axes.get_xaxis().set_ticklabels([])
    ax.axes.get_yaxis().set_ticklabels([])
    ax.axes.axis('tight')

plt.tight_layout()
fig.suptitle('pH seasonal flux', fontsize=16, y=1.02)

# %%
df_frame = sliced_data.to_dataframe()

# %%
# regional from 2015 to 2100

df_frame.describe()

# %%
start_date = "2090-01-01"
end_date = "2100-01-01"

ph_flux = sliced_data["ph"].sel(time_counter=slice(start_date, end_date))

# %%
ph_season_summary = ph_flux.groupby('time_counter.season').mean('time_counter', skipna=True)
ph_season_mean_all_years = ph_flux.resample(time_counter='QS-DEC', keep_attrs=True).mean()
ph_seasonal_mean = ph_season_mean_all_years.groupby('time_counter').mean(["y", "x"])

# %%
ph_season_summary

# %%
f, ax = plt.subplots(figsize=(16, 3))
ph_seasonal_mean.plot(marker="o",
                        color="grey",
                        markerfacecolor="black",
                        markeredgecolor="lightblue")
ax.set(title="Seasonal Mean pH flux")
plt.show()

# %%
colors = {3: "lightgreen", 6: "orange", 9: "black", 12: "lightblue"}
seasons = {3: "spring", 6: "summer", 9: "fall", 12: "winter"}

f, ax = plt.subplots(figsize=(16, 4))
for month, arr in ph_seasonal_mean.groupby('time_counter.month'):
    arr.plot(ax=ax,
             color="grey",
             marker="o",
             markerfacecolor=colors[month],
             markeredgecolor=colors[month],
             label=seasons[month])

ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set(title = "pH Change in CO2 flux Over Time")
plt.show()

# %%
ph_months_summary = ph_flux.groupby('time_counter.month').mean('time_counter', skipna=True)
ph_months_mean_all_years = ph_flux.resample(time_counter='MS', keep_attrs=True).mean()
ph_monthly_mean = ph_months_mean_all_years.groupby('time_counter').mean(["y", "x"])

# %%
colors = {1: "green", 2: "lightgreen", 3: "blue", 4: "lightblue", 5: "yellow", 6: "lightyellow", 7: "red", 8: "orange", 9: "purple", 10: "grey", 11: "lightgrey", 12: "black"}
months = {1: "january", 2: "february", 3: "march", 4: "april", 5: "may", 6: "june", 7: "july", 8: "august", 9: "september", 10: "october", 11: "november", 12: "december"}

f, ax = plt.subplots(figsize=(16, 4))
for month, arr in ph_monthly_mean.groupby('time_counter.month'):
    arr.plot(ax=ax,
             color="grey",
             marker="o",
             markerfacecolor=colors[month],
             markeredgecolor=colors[month],
             label=months[month])

ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax.set(title = "pH Change in CO2 flux Over Time")
plt.show()

# %%
sliced_frame = sliced_data.sel(time_counter=slice('2090', '2100'))

# %%
# regional from 2090 to 2100

ds_season_eu = sliced_frame.ph.groupby('time_counter.season').mean('time_counter')
fig_region, axes = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
i = 0
for j, season in enumerate(('DJF', 'MAM', 'JJA', 'SON')):
    if season =='JJA':
        i += 1
        j = 0
        
    elif season =='SON':
        j = 1
        
    ds_season.sel(season=season).plot.pcolormesh(
        ax=axes[j, i], vmin=7, vmax=8.50, cmap='RdBu_r',
        add_colorbar=True, extend='both')
    
for ax in axes.flat:
    ax.axes.get_xaxis().set_ticklabels([])
    ax.axes.get_yaxis().set_ticklabels([])
    ax.axes.axis('tight')

plt.tight_layout()
fig.suptitle('pH seasonal flux', fontsize=16, y=1.02)

# %%
df_baseline = sliced_frame.to_dataframe()

# %%
df_baseline_overview = df_baseline.describe()

# %%
df_baseline_overview.to_excel('pH_baseline_2090_2100_eu.xlsx')

# %%
# visualise the data with cartopy

plt.figure(figsize=(10, 4))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.add_feature(cfeature.LAND, zorder=100, facecolor='lightgrey', edgecolor='black')

sliced_frame.ph[0].plot.pcolormesh( # [] to select a month
    ax=ax, transform=ccrs.PlateCarree(), x="nav_lon", y="nav_lat", 
    add_colorbar=True
)
ax.coastlines()
ax.set_extent([-25, 10, 35, 70]) # plot a region
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hq/35w1hmb96js9vgqq4730r3780000gn/T/ipykernel_12442/562344538.py in <module>
#       5 ax.add_feature(cfeature.LAND, zorder=100, facecolor='lightgrey', edgecolor='black')
#       6
# ----> 7 sliced_frame.ph[0].plot.pcolormesh( # [] to select a month
#       8     ax=ax, transform=ccrs.PlateCarree(), x="nav_lon", y="nav_lat",
#       9     add_colorbar=True
#
# NameError: name 'sliced_frame' is not defined
