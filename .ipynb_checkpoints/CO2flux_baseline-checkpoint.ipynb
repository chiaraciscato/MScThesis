# %%
import netCDF4

# %%
import numpy as np

# %%
import cartopy.crs as ccrs

# %%
from netCDF4 import Dataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/hq/35w1hmb96js9vgqq4730r3780000gn/T/ipykernel_6185/1633401169.py in <module>
# ----> 1 from netCDF4 import Dataset
#
# ModuleNotFoundError: No module named 'netCDF4'

# %%
import matplotlib.pyplot as plt

# %%
import xarray as xr

# %%
Dataset=(r'/Users/chiaraciscato/Desktop/geomar/FOCI data/CO2flux_baseline_ensemble1_ssp126_1m.nc')

# %%
data = xr.open_dataset(Dataset)

# %%
lats = data.variables['nav_lat'][:]
lons = data.variables['nav_lon'][:]
time = data.variables['time_centered'][:]
co2flux = data.variables['co2flux_cpl'][:]

# %%
#plot coordinates
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(14, 4))
data.nav_lat.plot(ax=ax1)
data.nav_lon.plot(ax=ax2)

# %%
data.co2flux_cpl[505].plot()

# %%
plt.figure(figsize = (12, 6))
data.co2flux_cpl[1010].plot()

# %%
plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_global()
data.co2flux_cpl[0].plot.pcolormesh(
    ax=ax, transform=ccrs.PlateCarree(), x="nav_lon", y="nav_lat", add_colorbar=True
)
ax.coastlines()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hq/35w1hmb96js9vgqq4730r3780000gn/T/ipykernel_2525/1453146381.py in <module>
#       1 plt.figure(figsize=(12, 6))
# ----> 2 ax = plt.axes(projection=ccrs.PlateCarree())
#       3 ax.set_global()
#       4 data.co2flux_cpl[0].plot.pcolormesh(
#       5     ax=ax, transform=ccrs.PlateCarree(), x="nav_lon", y="nav_lat", add_colorbar=True
#
# NameError: name 'ccrs' is not defined

# %%
plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_global()
data.co2flux_cpl[0].plot.pcolormesh( #[] to select a month
    ax=ax, transform=ccrs.PlateCarree(), x="nav_lon", y="nav_lat", add_colorbar=True
)
ax.coastlines()
ax.set_extent([75, -70, 10, 60]) #Plot a region
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/hq/35w1hmb96js9vgqq4730r3780000gn/T/ipykernel_2525/2596155683.py in <module>
#       1 plt.figure(figsize=(12, 6))
# ----> 2 ax = plt.axes(projection=ccrs.PlateCarree())
#       3 ax.set_global()
#       4 data.co2flux_cpl[0].plot.pcolormesh( #[] to select a month
#       5     ax=ax, transform=ccrs.PlateCarree(), x="nav_lon", y="nav_lat", add_colorbar=True
#
# NameError: name 'ccrs' is not defined
