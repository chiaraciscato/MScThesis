# %%
import xarray

# %%
import glob
for file_name in glob.glob('/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/*'):
    print(file_name)
# Out:
# /Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20450101_20451231_diad_T.nc
# /Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20810101_20811231_diad_T.nc
# /Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20630101_20631231_diad_T.nc
# /Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20820101_20821231_diad_T.nc
# /Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20600101_20601231_diad_T.nc
# /Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20460101_20461231_diad_T.nc
# ...

# %%
import glob
print(glob.glob("/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/*"))
# Out:
# ['/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20450101_20451231_diad_T.nc', '/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20810101_20811231_diad_T.nc', '/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20630101_20631231_diad_T.nc', '/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20820101_20821231_diad_T.nc', '/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20600101_20601231_diad_T.nc', '/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20460101_20461231_diad_T.nc', '/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126
# ...

# %%
list_netcdf = []
for file_name in glob.glob("/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/*.nc"):
    list_netcdf.append(file_name)

# %%
print(list_netcdf)
# Out:
# ['/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20450101_20451231_diad_T.nc', '/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20810101_20811231_diad_T.nc', '/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20630101_20631231_diad_T.nc', '/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20820101_20821231_diad_T.nc', '/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20600101_20601231_diad_T.nc', '/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126os_2014CC105_1m_20460101_20461231_diad_T.nc', '/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/FOCI2.0-NM004_FM_ESM_SSP126
# ...

# %%
ds = xarray.open_mfdataset('/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_base/*.nc')

# %%
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:            (time_counter: 1020, bnds: 2, y: 511, x: 722)
# Coordinates:
#   * time_counter       (time_counter) datetime64[ns] 2015-01-16T12:00:00 ... ...
#     nav_lon            (y, x) float32 dask.array<chunksize=(511, 722), meta=np.ndarray>
#     nav_lat            (y, x) float32 dask.array<chunksize=(511, 722), meta=np.ndarray>
# Dimensions without coordinates: bnds, y, x
# Data variables:
#     time_counter_bnds  (time_counter, bnds) datetime64[ns] dask.array<chunksize=(12, 2), meta=np.ndarray>
#     co2flx             (time_counter, y, x) float32 dask.array<chunksize=(12, 511, 722), meta=np.ndarray>
#     ph                 (time_counter, y, x) float32 dask.array<chunksize=(12, 511, 722), meta=np.ndarray>
#     co2flux_cpl        (time_counter, y, x) float32 dask.array<chunksize=(12, 511, 722), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 1.9.8 (https://mpimet.mpg.de...
#     Conventions:  CF-1.5
# ...

# %%
ds.variables.keys()
# Out:
# KeysView(Frozen({'time_counter': <xarray.IndexVariable 'time_counter' (time_counter: 1020)>
# array(['2015-01-16T12:00:00.000000000', '2015-02-15T00:00:00.000000000',
#        '2015-03-16T12:00:00.000000000', ..., '2099-10-16T12:00:00.000000000',
#        '2099-11-16T00:00:00.000000000', '2099-12-16T12:00:00.000000000'],
#       dtype='datetime64[ns]')
# Attributes:
#     standard_name:  time
#     long_name:      Time axis
#     bounds:         time_counter_bnds
#     axis:           T, 'time_counter_bnds': <xarray.Variable (time_counter: 1020, bnds: 2)>
# dask.array<concatenate, shape=(1020, 2), dtype=datetime64[ns], chunksize=(12, 2), chunktype=numpy.ndarray>, 'nav_lon': <xarray.Variable (y: 511, x: 722)>
# dask.array<where, shape=(511, 722), dtype=float32, chunksize=(511, 722), chunktype=numpy.ndarray>
# Attributes:
#     standard_name:        longitude
#     long_name:            Longitude
#     units:                degrees_east
# ...

# %%
df = ds.sel(time_counter=slice('2025', '2040'))

# %%
dataframe = df.to_dataframe()

# %%
dataframe.head
# Out:
# <bound method NDFrame.head of                                  time_counter_bnds    nav_lon    nav_lat  \
# time_counter        bnds y   x
# 2025-01-16 12:00:00 0    0   0          2025-01-01  72.750000 -77.010475
#                              1          2025-01-01  73.250000 -77.010475
#                              2          2025-01-01  73.750000 -77.010475
#                              3          2025-01-01  74.250000 -77.010475
#                              4          2025-01-01  74.750000 -77.010475
# ...                                            ...        ...        ...
# 2040-12-16 12:00:00 1    510 717        2041-01-01  73.021080  50.315147
#                              718        2041-01-01  73.016090  50.182484
#                              719        2041-01-01  73.009857  50.065956
#                              720        2041-01-01  73.000015  49.995502
#                              721        2041-01-01  72.999985  49.995502
#
# ...

# %%
dataframe.describe()
# Out:
#             nav_lon       nav_lat        co2flx            ph   co2flux_cpl
# count  1.416737e+08  1.416737e+08  1.416737e+08  1.416737e+08  1.416737e+08
# mean  -1.019042e+00  5.077868e-01 -8.897915e-10  1.894744e+00 -7.261135e-10
# std    6.229314e+01  3.114657e+01  1.882129e-09  2.752994e+00  1.857863e-09
# min   -1.799970e+02 -7.701048e+01 -2.886090e-08  5.558515e+00 -2.358498e-08
# 25%   -9.518312e+01 -5.194667e+01 -1.897741e-09  7.751746e+00 -1.765586e-09
# 50%    2.482575e+00  2.998630e+00  0.000000e+00  7.976110e+00  0.000000e+00
# 75%    8.425000e+01  5.047917e+01  0.000000e+00  8.014486e+00  0.000000e+00
# max    1.799988e+02  8.988536e+01  4.803874e-08  8.332124e+00  4.259096e-08

# %%
ds.variables.keys()
# Out:
# KeysView(Frozen({'time_counter': <xarray.IndexVariable 'time_counter' (time_counter: 1020)>
# array(['2015-01-16T12:00:00.000000000', '2015-02-15T00:00:00.000000000',
#        '2015-03-16T12:00:00.000000000', ..., '2099-10-16T12:00:00.000000000',
#        '2099-11-16T00:00:00.000000000', '2099-12-16T12:00:00.000000000'],
#       dtype='datetime64[ns]')
# Attributes:
#     standard_name:  time
#     long_name:      Time axis
#     bounds:         time_counter_bnds
#     axis:           T, 'time_counter_bnds': <xarray.Variable (time_counter: 1020, bnds: 2)>
# dask.array<concatenate, shape=(1020, 2), dtype=datetime64[ns], chunksize=(12, 2), chunktype=numpy.ndarray>, 'nav_lon': <xarray.Variable (y: 511, x: 722)>
# dask.array<where, shape=(511, 722), dtype=float32, chunksize=(511, 722), chunktype=numpy.ndarray>
# Attributes:
#     standard_name:        longitude
#     long_name:            Longitude
#     units:                degrees_east
# ...

# %%
lats = ds.variables['nav_lat'][:]
lons = ds.variables['nav_lon'][:]
time = ds.variables['time_counter'][:]
ph = ds.variables['ph'][:]
co2flux = ds.variables['co2flux_cpl'][:].squeeze()
print(co2flux.shape)
# Out:
# (1020, 511, 722)

# %%
print(ph)
# Out:
# <xarray.Variable (time_counter: 1020, y: 511, x: 722)>
# dask.array<concatenate, shape=(1020, 511, 722), dtype=float32, chunksize=(12, 511, 722), chunktype=numpy.ndarray>
# Attributes:
#     long_name:           pH
#     online_operation:    average
#     interval_operation:  2160 s
#     interval_write:      1 month
#     cell_methods:        time: mean (interval: 2160 s)

# %%
ds.ph.mean(dim=('y', 'x'))
# Out:
# <xarray.DataArray 'ph' (time_counter: 1020)>
# dask.array<mean_agg-aggregate, shape=(1020,), dtype=float32, chunksize=(12,), chunktype=numpy.ndarray>
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 2015-01-16T12:00:00 ... 2099-...

# %%
ds.ph.mean(dim=('y', 'x')).plot() #global mean

# %%
for file_name in glob.glob('/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_oae/*'):
    print(file_name)
# Out:
# /Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_oae/FOCI2.0-TK201_FMESM_SSP126_alkEU_2014CC105_1m_20490101_20491231_diad_T.nc
# /Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_oae/FOCI2.0-TK201_FMESM_SSP126_alkEU_2014CC105_1m_20250101_20251231_diad_T.nc
# /Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_oae/FOCI2.0-TK201_FMESM_SSP126_alkEU_2014CC105_1m_20260101_20261231_diad_T.nc
# /Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_oae/FOCI2.0-TK201_FMESM_SSP126_alkEU_2014CC105_1m_20580101_20581231_diad_T.nc
# /Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_oae/FOCI2.0-TK201_FMESM_SSP126_alkEU_2014CC105_1m_20370101_20371231_diad_T.nc
# /Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_oae/FOCI2.0-TK201_FMESM_SSP126_alkEU_2014CC105_1m_20340101_20341231_diad_T.nc
# ...

# %%
ds_2 = xarray.open_mfdataset('/Users/chiaraciscato/Desktop/geomar/FOCI data/data_transfer/ph_co2flx_oae/*.nc')

# %%
ds_2.ph.mean(dim=('y', 'x'))
# Out:
# <xarray.DataArray 'ph' (time_counter: 1020)>
# dask.array<mean_agg-aggregate, shape=(1020,), dtype=float32, chunksize=(12,), chunktype=numpy.ndarray>
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 2015-01-16T12:00:00 ... 2099-...

# %%
ds_2.ph.mean(dim=('y', 'x')).plot() #global mean for pH

# %%
ds_2.ph.mean(dim=('time_counter')).plot()

# %%
#increased pH due to alkalinity enhancement in the selected region

# %%
ds.ph.mean(dim=('time_counter')).plot()

# %%
ds.co2flux_cpl.mean(dim=('time_counter')).plot() #global mean for co2flux without OAE

# %%
ds_2.co2flux_cpl.mean(dim=('time_counter')).plot() #global mean for co2flux with OAE
